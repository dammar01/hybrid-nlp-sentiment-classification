# %% [markdown]
# # v3 Training Dataset Audit

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'config.py').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

import config
from scripts.build_training_dataset import build_training_dataset

df, manifest = build_training_dataset()
manifest
# Out:
# {'row_count': 281,
#  'label_distribution': {'positif': 138, 'negatif': 82, 'netral': 61},
#  'metadata_recovery_distribution': {'matched_by_base_text_id': 281},
#  'group_count': 74,
#  'metadata_paths': ['E:\\School\\tugas-akhir\\project\\outputs\\datasets\\v1_candidate_labeling_dataset.csv',
#   'E:\\School\\tugas-akhir\\project\\outputs\\datasets\\v2_candidate_labeling_dataset.csv',
#   'E:\\School\\tugas-akhir\\project\\outputs\\datasets\\v3_candidate_labeling_dataset.csv',
#   'E:\\School\\tugas-akhir\\project\\outputs\\datasets\\v4_candidate_labeling_dataset.csv',
#   'E:\\School\\tugas-akhir\\project\\outputs\\datasets\\v5_candidate_labeling_dataset.csv',
#   'E:\\School\\tugas-akhir\\project\\outputs\\datasets\\v6_candidate_labeling_dataset.csv',
#   'E:\\School\\tugas-akhir\\project\\outputs\\datasets\\v7_candidate_labeling_dataset.csv',
#   'E:\\School\\tugas-akhir\\project\\outputs\\datasets\\v8_candidate_labeling_dataset.csv'],
#  'gates': {'total_is_281': True,
#   'positif_is_138': True,
#   'negatif_is_82': True,
#   'netral_is_61': True,
#   'unknown_label_is_0': True,
#   'empty_text_is_0': True,
#   'duplicate_normalized_text_is_0': True,
#   'empty_group_id_is_0': True},
#  'all_gates_passed': True,
#  'label_mapping': {'negatif': 0, 'netral': 1, 'positif': 2}}

# %%
df.head(20)
# Out:
# shape: (20, 15)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ text_id   ┆ base_text ┆ original_ ┆ processed ┆ … ┆ group_sou ┆ metadata_ ┆ golden_fi ┆ metadata │
# │ ---       ┆ _id       ┆ text      ┆ _text     ┆   ┆ rce       ┆ recovery_ ┆ le        ┆ _source_ │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ status    ┆ ---       ┆ path     │
# │           ┆ str       ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ str       ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ RAW-0560# ┆ RAW-0560  ┆ Optimalis ┆ optimalis ┆ … ┆ normalize ┆ matched_b ┆ 1_sentime ┆ E:\Schoo │
# │ 01        ┆           ┆ asi pola  ┆ asi pola  ┆   ┆ d_source_ ┆ y_base_te ┆ nt_labeli ┆ l\tugas- │
# │           ┆           ┆ operasi   ┆ operasi   ┆   ┆ url       ┆ xt_id     ┆ ng_output ┆ akhir\pr │
# │           ┆           ┆ meng…     ┆ meng…     ┆   ┆           ┆           ┆ .js…      ┆ oject\…  │
# │ RAW-0560# ┆ RAW-0560  ┆ Penelitia ┆ penelitia ┆ … ┆ normalize ┆ matched_b ┆ 1_sentime ┆ E:\Schoo │
# │ 02        ┆           ┆ n ini men ┆ n ini men ┆   ┆ d_source_ ┆ y_base_te ┆ nt_labeli ┆ l\tugas- │
# │           ┆           ┆ gusulkan  ┆ gusulkan  ┆   ┆ url       ┆ xt_id     ┆ ng_output ┆ akhir\pr │
# │           ┆           ┆ pen…      ┆ pen…      ┆   ┆           ┆           ┆ .js…      ┆ oject\…  │
# │ RAW-0485# ┆ RAW-0485  ┆ Saya      ┆ saya      ┆ … ┆ normalize ┆ matched_b ┆ 1_sentime ┆ E:\Schoo │
# │ 01        ┆           ┆ Sangat    ┆ sangat    ┆   ┆ d_source_ ┆ y_base_te ┆ nt_labeli ┆ l\tugas- │
# │           ┆           ┆ Setuju    ┆ setuju    ┆   ┆ url       ┆ xt_id     ┆ ng_output ┆ akhir\pr │
# │           ┆           ┆ dengan    ┆ dengan    ┆   ┆           ┆           ┆ .js…      ┆ oject\…  │
# │           ┆           ┆ Stat…     ┆ stat…     ┆   ┆           ┆           ┆           ┆          │
# │ RAW-0485# ┆ RAW-0485  ┆ Dan       ┆ dan       ┆ … ┆ normalize ┆ matched_b ┆ 1_sentime ┆ E:\Schoo │
# │ 02        ┆           ┆ Masukan   ┆ masukan   ┆   ┆ d_source_ ┆ y_base_te ┆ nt_labeli ┆ l\tugas- │
# │           ┆           ┆ Saya      ┆ saya      ┆   ┆ url       ┆ xt_id     ┆ ng_output ┆ akhir\pr │
# │           ┆           ┆ Kepada    ┆ kepada    ┆   ┆           ┆           ┆ .js…      ┆ oject\…  │
# │           ┆           ┆ Pemeri…   ┆ pemeri…   ┆   ┆           ┆           ┆           ┆          │
# │ RAW-0908# ┆ RAW-0908  ┆ Hal ini   ┆ hal ini   ┆ … ┆ normalize ┆ matched_b ┆ 1_sentime ┆ E:\Schoo │
# │ 01        ┆           ┆ menunjukk ┆ menunjukk ┆   ┆ d_source_ ┆ y_base_te ┆ nt_labeli ┆ l\tugas- │
# │           ┆           ┆ an bahwa  ┆ an bahwa  ┆   ┆ url       ┆ xt_id     ┆ ng_output ┆ akhir\pr │
# │           ┆           ┆ seju…     ┆ seju…     ┆   ┆           ┆           ┆ .js…      ┆ oject\…  │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ RAW-1126# ┆ RAW-1126  ┆ Ia juga   ┆ ia juga   ┆ … ┆ normalize ┆ matched_b ┆ 1_sentime ┆ E:\Schoo │
# │ 02        ┆           ┆ mengataka ┆ mengataka ┆   ┆ d_source_ ┆ y_base_te ┆ nt_labeli ┆ l\tugas- │
# │           ┆           ┆ n selain  ┆ n selain  ┆   ┆ url       ┆ xt_id     ┆ ng_output ┆ akhir\pr │
# │           ┆           ┆ infr…     ┆ infr…     ┆   ┆           ┆           ┆ .js…      ┆ oject\…  │
# │ RAW-0866# ┆ RAW-0866  ┆ Sekda     ┆ sekda     ┆ … ┆ normalize ┆ matched_b ┆ 1_sentime ┆ E:\Schoo │
# │ 01        ┆           ┆ berharap, ┆ berharap, ┆   ┆ d_source_ ┆ y_base_te ┆ nt_labeli ┆ l\tugas- │
# │           ┆           ┆ mudah-mud ┆ mudah-mud ┆   ┆ url       ┆ xt_id     ┆ ng_output ┆ akhir\pr │
# │           ┆           ┆ ahan …    ┆ ahan …    ┆   ┆           ┆           ┆ .js…      ┆ oject\…  │
# │ RAW-0866# ┆ RAW-0866  ┆ Sekda     ┆ sekda     ┆ … ┆ normalize ┆ matched_b ┆ 1_sentime ┆ E:\Schoo │
# │ 02        ┆           ┆ Kabupaten ┆ kabupaten ┆   ┆ d_source_ ┆ y_base_te ┆ nt_labeli ┆ l\tugas- │
# │           ┆           ┆ Ketapang  ┆ ketapang  ┆   ┆ url       ┆ xt_id     ┆ ng_output ┆ akhir\pr │
# │           ┆           ┆ pun m…    ┆ pun m…    ┆   ┆           ┆           ┆ .js…      ┆ oject\…  │
# │ RAW-0866# ┆ RAW-0866  ┆ Pemerinta ┆ pemerinta ┆ … ┆ normalize ┆ matched_b ┆ 1_sentime ┆ E:\Schoo │
# │ 03        ┆           ┆ h         ┆ h         ┆   ┆ d_source_ ┆ y_base_te ┆ nt_labeli ┆ l\tugas- │
# │           ┆           ┆ Kabupaten ┆ kabupaten ┆   ┆ url       ┆ xt_id     ┆ ng_output ┆ akhir\pr │
# │           ┆           ┆ siap      ┆ siap      ┆   ┆           ┆           ┆ .js…      ┆ oject\…  │
# │           ┆           ┆ memb…     ┆ memb…     ┆   ┆           ┆           ┆           ┆          │
# │ RAW-0307# ┆ RAW-0307  ┆ Integrasi ┆ integrasi ┆ … ┆ normalize ┆ matched_b ┆ 1_sentime ┆ E:\Schoo │
# │ 01        ┆           ┆ GREEN-VOL ┆ green-vol ┆   ┆ d_source_ ┆ y_base_te ┆ nt_labeli ┆ l\tugas- │
# │           ┆           ┆ T dengan  ┆ t dengan  ┆   ┆ url       ┆ xt_id     ┆ ng_output ┆ akhir\pr │
# │           ┆           ┆ Sm…       ┆ sm…       ┆   ┆           ┆           ┆ .js…      ┆ oject\…  │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df.group_by(['metadata_recovery_status', 'group_source']).len().sort(['metadata_recovery_status', 'group_source'])
# Out:
# shape: (1, 3)
# ┌──────────────────────────┬───────────────────────┬─────┐
# │ metadata_recovery_status ┆ group_source          ┆ len │
# │ ---                      ┆ ---                   ┆ --- │
# │ str                      ┆ str                   ┆ u32 │
# ╞══════════════════════════╪═══════════════════════╪═════╡
# │ matched_by_base_text_id  ┆ normalized_source_url ┆ 281 │
# └──────────────────────────┴───────────────────────┴─────┘
