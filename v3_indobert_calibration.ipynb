# %% [markdown]
# # v3 IndoBERT Calibration

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'config.py').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

import config
from services.artifact_service import ArtifactService

EXPERIMENT_DIR = Path(config.EXPERIMENT_CONFIG['artifact_root']) / 'hybrid_indobert_socal_manual'
print('CLI: python main.py calibrate-indobert --experiment-dir', EXPERIMENT_DIR)

# %%
artifact = ArtifactService()
calibration_path = EXPERIMENT_DIR / 'calibration_artifact.json'
fusion_path = EXPERIMENT_DIR / 'fusion_policy.json'

if calibration_path.exists():
    display(artifact.load_json(calibration_path))
else:
    print('Calibration artifact belum ada.')

if fusion_path.exists():
    display(artifact.load_json(fusion_path))
else:
    print('Fusion policy belum ada.')
